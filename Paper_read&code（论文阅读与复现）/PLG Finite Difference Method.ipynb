# %% [markdown]
# 主要还是学习回溯的想法，三角格和主格之间用D阶置换群来通信；用部分置换的想法来把问题分解成为顺序操作，从而可以回溯
#
# 用回溯法来生成一个适定的三角格，以便于对边界进行拉格朗日插值。回溯的顺序用到了部分置换群，但整体还是属于传统数据结构与算法的内容
#
# 主要还是为了处理边界条件，但算法理解有待继续深入
#
# 有个小意外的发现是最小二乘的条件数随膨胀先小后急剧升高
